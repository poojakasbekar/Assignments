# %% [markdown]
# ### Assignment no 7

# %%
# 1. Write a Python program to read an entire text file

import os
a=open('data.txt',"r")
print(a.read())
a.close()
# Out:
# Python
# data
# science
# hello
# we
# are learning
# nlp
# meachine learning

# %%
import glob
glob.glob('*.txt')
# Out:
# ['data2.txt', 'deep_learning.txt', 'python data science.txt', 'Python.txt']

# %%
# 2.  Write a Python program to read the first n lines of a file.
n = int(input("\n\t\tEnter Lines To Read : "))
f = open("data2.txt","r")
for i in range(n):
     print(f.readline())
# Out:
# 		Enter Lines To Read : 5
# data
#
# hello
#
# we are learning
#
# meachine learning
#
# Good Morning Tutorials Point

# %%
# 3. Write a Python program to append text to a file and display the text.

with open("python data science.txt", "a") as f:
   f.write("hello we are adding new line in file")

# %% [markdown]
# ## ![image.png](attachment:image.png)

# %% [markdown]
# ####  ![image.png](attachment:image.png)

# %%
# 4. Write a Python program to read the last n lines of a file

a_file = open("python data science.txt", "r")
lines = a_file.readlines()
last_lines = lines[-5:]

print(last_lines)
a_file.close()
# Out:
# ['hello\n', 'we \n', 'are learning \n', 'nlp\n', 'meachine learninghello we are adding new line in file']

# %%
# 5. Write a Python program to read a file line by line and store it into a list

with open("python data science.txt","r") as f:
#Content_list is the list that contains the read lines.     
    content_list = f.readlines()
    print(content_list)
# Out:
# ['Python\n', 'data\n', 'science\n', 'hello\n', 'we \n', 'are learning \n', 'nlp\n', 'meachine learninghello we are adding new line in file']

# %%
# 6. Write a Python program to count the number of lines in a text file
with open("python data science.txt","r") as f:
    lines=len(f.readlines())
    print("total number of lines:",lines)
# Out:
# total number of lines: 8

# %%
# 7. Write a Python program to count the frequency of words in a file

from collections import Counter
def word_count(fname):
        with open(fname) as f:
                return Counter(f.read().split())

print("Number of words in the file :",word_count("python data science.txt"))
# Out:
# Number of words in the file : Counter({'we': 2, 'are': 2, 'Python': 1, 'data': 1, 'science': 1, 'hello': 1, 'learning': 1, 'nlp': 1, 'meachine': 1, 'learninghello': 1, 'adding': 1, 'new': 1, 'line': 1, 'in': 1, 'file': 1})

# %%
# 8. Write a Python program to copy the contents of a file to another file

with open("deep_learning.txt") as f:
    with open("Python.txt","w") as f1:
        for line in f:
            f1.write(line)

# %% [markdown]
# ###  ![image.png](attachment:image.png)

# %% [markdown]
# #### copy the content of another file.
#
# ###  ![image.png](attachment:image.png)

# %%
# 9. Write a Python script to display the various Date Time formats - Go to the editor

# a) Current date and time.
# b) Current year
# c) Month of year
# d) Week number of the year
# e) Weekday of the week
# f) Day of year
# g) Day of the month
# h) Day of week

# %%
import time
import datetime
print("current date and time:",datetime.datetime.now())
print("current year:",datetime.date.today().strftime("%Y"))
print("Month of year:",datetime.date.today().strftime("%B"))
print("week number of year:",datetime.date.today().strftime("%W"))
print("weekday of the week:",datetime.date.today().strftime("%w"))
print("Day of year:",datetime.date.today().strftime("%j"))
print("Day of the month:",datetime.date.today().strftime("%d"))
print("Day of week:",datetime.date.today().strftime("%A"))
# Out:
# current date and time: 2022-10-11 11:55:59.897857
# current year: 2022
# Month of year: October
# week number of year: 41
# weekday of the week: 2
# Day of year: 284
# Day of the month: 11
# Day of week: Tuesday

# %%
# 10. Write a Python program to determine whether a given year is a leap year
year=int(input("Enter year to be checked:"))
if(year%4==0 and year%100!=0 or year%400==0):
    print("The year is a leap year!")
else:
    print("The year is not a leap year!")
# Out:
# Enter year to be checked:2022
# The year is not a leap year!

# %%
# 11. Write a Python program to convert a string to datetime. Go to the editor
# ○ Sample String : Jul 1 2014 2:43PM
# ○ Expected Output : 2014-07-01 14:43:00

from datetime import datetime
date_res = datetime.strptime('Jul 1 2014 2:43PM','%b %d %Y %I:%M%p')
print(date_res)
# Out:
# 2014-07-01 14:43:00

# %%
# 12. Write a Python program to subtract five days from current date
from datetime import date , timedelta
dt=date.today() - timedelta(5)
print("current date",date.today())
print("five days before current date:",dt)
# Out:
# current date 2022-10-11
# five days before current date: 2022-10-06

# %%
# 13.Write a Python program to print yesterday, today, tomorrow
import datetime
today=datetime.date.today()
yesterday=today - datetime.timedelta(days=1)
tomorrow=today + datetime.timedelta(days=1)
print("Yestreday:",yesterday)
print("Today:   ",today)
print("Tomorrow:",tomorrow)
# Out:
# Yestreday: 2022-10-10
# Today:    2022-10-11
# Tomorrow: 2022-10-12

# %%
# 14. Write a Python program to print next 5 days starting from today

import datetime
today=datetime.datetime.today()

for i in range(0,5):
    print(today + datetime.timedelta(days=i))
# Out:
# 2022-10-11 12:30:41.397753
# 2022-10-12 12:30:41.397753
# 2022-10-13 12:30:41.397753
# 2022-10-14 12:30:41.397753
# 2022-10-15 12:30:41.397753

# %%
# 15. Write a Python program to drop microseconds from DateTime
import datetime
dt = datetime.datetime.today()  
print(dt)
dt1 = datetime.datetime.today().replace(microsecond=0)
print(dt1)
# Out:
# 2022-10-11 13:55:36.552102
# 2022-10-11 13:55:36

# %%
# 16. Write a Python program to find the date of the first Monday of a given week

import time
print(time.asctime(time.strptime('2022 41 1', '%Y %W %w')))
# Out:
# Mon Oct 10 00:00:00 2022

# %%
# 17. Write a Python program to select all the Sundays of a specified year
year = input('Enter a year : ')
sundays = datetime.datetime.strptime(year+'0'+'0','%Y%W%w').date()
print(sundays)
for i in range(52):
    sundays += datetime.timedelta(days = 7)
    print(sundays)
# Out:
# Enter a year : 2022
# 2022-01-02
# 2022-01-09
# 2022-01-16
# 2022-01-23
# 2022-01-30
# 2022-02-06
# 2022-02-13
# 2022-02-20
# 2022-02-27
# 2022-03-06
# 2022-03-13
# 2022-03-20
# 2022-03-27
# 2022-04-03
# 2022-04-10
# 2022-04-17
# 2022-04-24
# 2022-05-01
# 2022-05-08
# 2022-05-15
# 2022-05-22
# 2022-05-29
# 2022-06-05
# 2022-06-12
# 2022-06-19
# 2022-06-26
# 2022-07-03
# 2022-07-10
# 2022-07-17
# 2022-07-24
# 2022-07-31
# 2022-08-07
# 2022-08-14
# 2022-08-21
# 2022-08-28
# 2022-09-04
# 2022-09-11
# 2022-09-18
# 2022-09-25
# 2022-10-02
# 2022-10-09
# 2022-10-16
# 2022-10-23
# 2022-10-30
# 2022-11-06
# 2022-11-13
# 2022-11-20
# 2022-11-27
# 2022-12-04
# 2022-12-11
# 2022-12-18
# 2022-12-25
# 2023-01-01

# %%
# 18. Write a Python program to create a file and write some text and rename the file name

with open('file1.txt','w') as f:
    f.write('Welcome and hello we are learning python and data science')
if not os.path.exists('file1_rename.txt'):
    os.rename('file1.txt','file1_rename.txt')

# %% [markdown]
# ## I write text in file1.txt file it will write the text on file1.txt file and then we rename the file name as file1.txt to file1_rename.txt
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ### 19. What are different methods available in the OS module for creating a directory?
#
# There are different methods available in the OS module for creating a director. These are –
#
# 1) os.mkdir()
# 2) os.makedirs()
#
# 1) Using os.mkdir()
# os.mkdir() method in Python is used to create a directory named path with the specified numeric mode.
# This method raise FileExistsError if the directory to be created already exists.
#
# 2) Using os.makedirs()
# os.makedirs() method in Python is used to create a directory recursively.
# That means while making leaf directory if any intermediate-level directory is missing,
# os.makedirs() method will create them all

# %% [markdown]
# ### 20. Explain os.listdir() method.
#
# os.listdir() method in python is used to get the list of all files and directories in the specified directory.
# If we don’t specify any directory,
# then list of files and directories in the current working directory will be returned.
#
# Syntax: os.listdir(path)

# %% [markdown]
# ### 21. What are different methods for removing directories and files in Python?
# Python provides different methods and functions for removing files and directories.
# One can remove the file according to their need.
#
# Various methods provided by Python are –
#
# Using os.remove()
# Using os.rmdir()
# Using shutil.rmtree()
# Using pathlib.Path(empty_dir_path).rmdir()
#
# 1) Deleting file/dir using the os.remove() method
# os.remove() method in Python is used to remove or delete a file path.
# This method can not remove or delete a directory.
# If the specified path is a directory then OSError will be raised by the method.
#
# :-Syntax of os.remove()
#
# Syntax: os.remove(path, *, dir_fd = None)
#
#
# 2) Deleting file/dir using the os.rmdir() method
# os.rmdir() method in Python is used to remove or delete an empty directory.
# OSError will be raised if the specified path is not an empty directory.
#
# :- Syntax of os.rmdir()
# syntax: os.rmdir(path, *, dir_fd = None)
#
# 3) Deleting file/dir using the shutil.rmtree()
# shutil.rmtree() is used to delete an entire directory tree, a path must point to a directory
# (but not a symbolic link to a directory).
#
#
# :- Syntax of shutil.rmtree()
# Syntax: shutil.rmtree(path, ignore_errors=False, onerror=None)
#
#
# 4) Deleting file/dir using the pathlib.Path(empty_dir_path).rmdir()
# An empty directory can also be removed or deleted using the pathlib module’s rmdir() method.
# First, we have to set the path for the directory, and then we call the rmdir() method on that path
#
# :- Syntax of pathlib.Path
# Syntax: pathlib.Path(empty_dir_path).rmdir()

# %% [markdown]
# ### 22. What are exceptions in Python
#
# An Exception is an error that happens during
# the execution of a program.
# Whenever there is an error,
# Python generates an exception that could be handled.
# It basically prevents the program from getting crashed.

# %% [markdown]
# ### 23. What are Built-in exceptions
#
# Built-in exceptions
#
# 1)ArithmeticError:-
# Raised when an error occurs in numeric calculations
#
# 2)AssertionError:-
# Raised when an assert statement fails
#
# 3)AttributeError:-
# Raised when attribute reference or assignment fails
#
# 4)Exception:-
# Base class for all exceptions
#
# 5)EOFError:-
# Raised when the input() method hits an "end of file" condition (EOF)
#
# 6)FloatingPointError:-
# Raised when a floating point calculation fails
#
# 7)GeneratorExit:-
# Raised when a generator is closed (with the close() method)
#
# 8)ImportError:-
# Raised when an imported module does not exist
#
# 9)IndentationError:-
# Raised when indendation is not correct
#
# 10)IndexError:-
# Raised when an index of a sequence does not exist
#
# 11)KeyError:-
# Raised when a key does not exist in a dictionary
#
# 12)KeyboardInterrupt:-
# Raised when the user presses Ctrl+c, Ctrl+z or Delete
#
# 13)LookupError:-
# Raised when errors raised cant be found
#
# 14)MemoryError:-
# Raised when a program runs out of memory
#
# 15)NameError:-
# Raised when a variable does not exist
#
# 16)NotImplementedError:-
# Raised when an abstract method requires an inherited class to override the method
#
# 17)OSError:-
# Raised when a system related operation causes an error
#
# 18)OverflowError:-
# Raised when the result of a numeric calculation is too large
#
# 19)ReferenceError:-
# Raised when a weak reference object does not exist
#
# 20)RuntimeError:-
# Raised when an error occurs that do not belong to any specific expections
#
# 21)StopIteration:-
# Raised when the next() method of an iterator has no further values
#
# 22)SyntaxError:-
# Raised when a syntax error occurs
#
# 23)TabError:-
# Raised when indentation consists of tabs or spaces
#
# 24)SystemError:-
# Raised when a system error occurs
#
# 25)SystemExit:-
# Raised when the sys.exit() function is called
#
# 26)TypeError:-
# Raised when two different types are combined
#
# 27)UnboundLocalError:-
# Raised when a local variable is referenced before assignment
#
# 28)UnicodeError:-
# Raised when a unicode problem occurs
#
# 29)UnicodeEncodeError:-
# Raised when a unicode encoding problem occurs
#
# 30)UnicodeDecodeError:-
# Raised when a unicode decoding problem occurs
#
# 31)UnicodeTranslateError:-
# Raised when a unicode translation problem occurs
#
# 32)ValueError:-
# Raised when there is a wrong value in a specified data type
#
# 33)ZeroDivisionError:-
# Raised when the second operator in a division is zero

# %% [markdown]
# ### 24. What are User-defined Exceptions?
# It stops the program's execution if the error occurs and raises an exception.
# Some commonly raised Exceptions are ArithmeticError,
# AttributeError, ImportError, IOError, FileNotFoundError, etc.
#
# to create a User-defined Exception,
# we need to create a class directly or indirectly derived from the built-in Exception class.

# %% [markdown]
# ### 25. When would you not use try-except?
# a) When the code is very large, using try except will make it difficult to locate
# error
# b) One needs to be very specific while handling exception, else it becomes difficult
# to troubleshoot the error.
# c) When we know there is less probability of occurance of any logical error.

# %%
# 26. Can try-except catch the error if a file can’t be opened
try:
    with open("file.pdf","r") as f:
        f.read()
except Exception as e:
    print(e)
print('WELCOME')
# Out:
# [Errno 2] No such file or directory: 'file.pdf'
# WELCOME
